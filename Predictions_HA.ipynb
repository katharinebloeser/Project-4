# %% [markdown]
# <a href="https://colab.research.google.com/github/katharinebloeser/Project-4/blob/main/Predictions_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import pandas as pd
import csv
from google.colab import files
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
#Upload the dataset
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b973bb5b-dddb-4c8c-9d82-e3054b0908f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b973bb5b-dddb-4c8c-9d82-e3054b0908f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pred_ha_df = pd.read_csv('final_df_rn2.csv')
pred_ha_df.head()
# Out:
#    drink_alcohol  alcohol_per_day  high_bp  high_cholesterol  \
# 0            1.0         1.000000      1.0               1.0
# 1            1.0         4.000000      1.0               1.0
# 2            1.0         3.489349      1.0               1.0
# 3            1.0         3.489349      1.0               2.0
# 4            1.0         1.000000      1.0               1.0
#
#    cholesterol_prescription  grocery_budget  nonfood_budget  food_budget  \
# 0                       1.0           300.0             0.0         50.0
# 1                       1.0           642.0           214.0        128.0
# 2                       1.0           150.0            25.0          0.0
# 3                       2.0           200.0             0.0         40.0
# 4                       1.0           150.0            60.0          0.0
#
#    restaurant_budget  food_delivery_budget  ...  relative_asthma  \
# 0                0.0                  85.0  ...              1.0
# ...

# %%
#scale sleep_hours, age, gender, gender2
scaled = StandardScaler().fit_transform(pred_ha_df[['sleep_hours', 'age', 'gender', 'gender2']])
scaled_df = pd.DataFrame(scaled, columns=['sleep_hours', 'age', 'gender', 'gender2'])
scaled_df.head()
# Out:
#    sleep_hours       age    gender  gender2
# 0     0.000000  1.153672 -1.044703  -0.9251
# 1     0.000000  0.292081 -1.044703  -0.9251
# 2     0.968446  1.325990 -1.044703  -0.9251
# 3     0.000000  1.383429  0.957210  -0.9251
# 4    -1.273791  0.406959 -1.044703  -0.9251

# %%
#concatinate scaled_df with pred_ha_df replacing the pred_ha_df values with the scaled values
pred_ha_df[['sleep_hours', 'age', 'gender', 'gender2']] = scaled_df
pred_ha_df.head()
# Out:
#    drink_alcohol  alcohol_per_day  high_bp  high_cholesterol  \
# 0            1.0         1.000000      1.0               1.0
# 1            1.0         4.000000      1.0               1.0
# 2            1.0         3.489349      1.0               1.0
# 3            1.0         3.489349      1.0               2.0
# 4            1.0         1.000000      1.0               1.0
#
#    cholesterol_prescription  grocery_budget  nonfood_budget  food_budget  \
# 0                       1.0           300.0             0.0         50.0
# 1                       1.0           642.0           214.0        128.0
# 2                       1.0           150.0            25.0          0.0
# 3                       2.0           200.0             0.0         40.0
# 4                       1.0           150.0            60.0          0.0
#
#    restaurant_budget  food_delivery_budget  ...  relative_asthma  \
# 0                0.0                  85.0  ...              1.0
# ...

# %%
#print the unique values for heart_attack
print(pred_ha_df['heart_attack'].unique())
# Out:
# [0. 1.]

# %%
#drop column menstruate from the dataframe
pred_ha_df = pred_ha_df.drop(columns = ['menstruate'])

# %%
#separate the features (x) from the target (Y)
y = pred_ha_df["heart_attack"]
X = pred_ha_df.drop(columns="heart_attack")

# %%
#create the training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (4324, 84)

# %%
logistic_regression_model = LogisticRegression(max_iter = 2000, random_state = 9, solver = 'liblinear')
lr_model = logistic_regression_model.fit(X_train, y_train)

# %%
#generate the training predictions
training_predictions = lr_model.predict(X_train)

#generate the testing predictions
testing_predictions = lr_model.predict(X_test)

# %%
#create and save the confusion matrix for the training data
training_matrix = confusion_matrix(y_train, training_predictions)
training_matrix

# %%
#create and save the confusion matrix for the testing data
testing_matrix = confusion_matrix(y_test, testing_predictions)
testing_matrix

# %%
#create and save the training classification report
training_report = classification_report(y_train, training_predictions)
print(training_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      4152
#            1       0.00      0.00      0.00       172
#
#     accuracy                           0.96      4324
#    macro avg       0.48      0.50      0.49      4324
# weighted avg       0.92      0.96      0.94      4324
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#create and save the testing classification reprot
testing_report = classification_report(y_test, testing_predictions)
print(testing_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1384
#            1       0.00      0.00      0.00        58
#
#     accuracy                           0.96      1442
#    macro avg       0.48      0.50      0.49      1442
# weighted avg       0.92      0.96      0.94      1442

# %%
#get the feature importance array
importances = np.abs(logistic_regression_model.coef_[0])
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance':importances})
importance_df_sorted = importance_df.sort_values('Importance', ascending=False)
top_10_importances = importance_df_sorted.head(10)
print(top_10_importances)
# Out:
#                      Feature  Importance
# 78                       age    0.209983
# 58    coronary_heart_disease    0.127504
# 77                    gender    0.099038
# 4   cholesterol_prescription    0.098978
# 2                    high_bp    0.093982
# 57  congestive_heart_failure    0.089302
# 47            monthly_income    0.088194
# 3           high_cholesterol    0.076688
# 41            general_health    0.073359
# 55         blood_transfusion    0.072522
