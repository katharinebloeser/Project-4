# %% [markdown]
# <a href="https://colab.research.google.com/github/katharinebloeser/Project-4/blob/main/Predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import pandas as pd
import csv
from google.colab import files
from google.colab import drive
from sklearn.model_selection import train_test_split

# %%
#Upload the dataset
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f5c24f63-3178-4325-b432-cebcb1b1d06e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5c24f63-3178-4325-b432-cebcb1b1d06e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pred_dm_df = pd.read_csv('final_df_rn.csv')
pred_dm_df.head()
# Out:
#    speak_english  speak_english2  drink_alcohol  alcohol_per_day  \
# 0            1.0        1.000000       1.000000         1.000000
# 1            1.0        1.000000       1.000000         4.000000
# 2            1.0        1.099414       1.000000         3.511123
# 3            1.0        1.000000       1.311197         3.511123
# 4            1.0        1.099414       1.000000         3.511123
#
#    ear_infections  high_bp  measure_bp_home  measure_bp_doctor  \
# 0        2.000000  1.00000          2.00000            2.00000
# 1        2.000000  1.00000          1.00000            2.00000
# 2        2.000000  1.00000          2.00000            2.00000
# 3        1.939187  1.66909          1.75789            1.86742
# 4        2.000000  1.00000          1.00000            2.00000
#
#    cholesterol_checked  cholesterol_checked_1y  ...   height_in  \
# 0             1.660267                1.000000  ...   69.000000
# ...

# %%
#make columns a list to view all of them
pred_dm_df.columns.to_list()
# Out:
# ['speak_english',
#  'speak_english2',
#  'drink_alcohol',
#  'alcohol_per_day',
#  'ear_infections',
#  'high_bp',
#  'measure_bp_home',
#  'measure_bp_doctor',
#  'cholesterol_checked',
#  'cholesterol_checked_1y',
#  'high_cholesterol',
#  'cholesterol_prescription',
#  'grocery_budget',
#  'nonfood_budget',
#  'food_budget',
#  'restaurant_budget',
#  'food_delivery_budget',
#  'fast_food',
#  'saw_nutrition_fast_food',
#  'use_nutrition_fast_food',
#  'eat_restaurants',
#  'eat_chain_restaurants',
#  'saw_nutrition_restaurant',
#  'use_nutrition_restaurant',
#  'saw_my_plate',
#  'chest_pain_ever',
#  'short_breath_stairs',
#  'sensative_smell',
#  'loss_of_taste',
#  'taste_in_mouth',
#  'dry_mouth',
#  'nasal_congestion',
#  'wisdom_teeth_removed',
#  'tonsils_removed',
#  'head_injury',
#  'broken_nose',
#  'sinus_infections',
#  'meals_not_homemade',
#  'meals_fast_food',
#  'meals_prepackaged',
#  'frozen_meals_per_month',
#  'milk_product_per_month',
#  'milk_drinker',
# ...

# %%
#separate the features (x) from the target (Y)
y = pred_dm_df["diabetes"]
X = pred_dm_df.drop(columns="diabetes")

# %%
#show all unique values of diabetes
y.unique()
# Out:
# array([1.        , 0.        , 1.94758931, 3.        , 9.        ,
#        7.        ])

# %%
#recode Y dataframe so diabetes =1 or 0 not 2
y = y.replace(2, 0)
y.head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    0.0
# Name: diabetes, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=1,
                                                    stratify=y)
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a59add7dcc6d> in <cell line: 1>()
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X,
#       2                                                     y,
#       3                                                     random_state=1,
#       4                                                     stratify=y)
#       5 X_train.shape
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# ...
