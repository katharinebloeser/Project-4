# %% [markdown]
# <a href="https://colab.research.google.com/github/katharinebloeser/Project-4/blob/main/Predictions_DM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pathlib import Path
import pandas as pd
import csv
from google.colab import files
from google.colab import drive
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
#Upload the dataset
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b73cb07b-39c9-457f-80df-89ed050db624" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b73cb07b-39c9-457f-80df-89ed050db624">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pred_dm_df = pd.read_csv('final_df_rn.csv')
pred_dm_df.head()
# Out:
#    speak_english  speak_english2  drink_alcohol  alcohol_per_day  \
# 0            1.0        1.000000       1.000000         1.000000
# 1            1.0        1.000000       1.000000         4.000000
# 2            1.0        1.099414       1.000000         3.482488
# 3            1.0        1.000000       1.299834         3.482488
# 4            1.0        1.099414       1.000000         3.482488
#
#    ear_infections   high_bp  measure_bp_home  measure_bp_doctor  \
# 0        2.000000  1.000000         2.000000           2.000000
# 1        2.000000  1.000000         1.000000           2.000000
# 2        2.000000  1.000000         2.000000           2.000000
# 3        1.811049  1.663415         1.755648           1.866625
# 4        2.000000  1.000000         1.000000           2.000000
#
#    cholesterol_checked  cholesterol_checked_1y  ...   height_in  \
# 0             1.395365                1.000000  ...   69.000000
# ...

# %%
#scale sleep_hours, age, gender, gender2
scaled = StandardScaler().fit_transform(pred_dm_df[['sleep_hours', 'age', 'gender', 'gender2']])
scaled_df = pd.DataFrame(scaled, columns=['sleep_hours', 'age', 'gender', 'gender2'])
scaled_df.head()
# Out:
#     sleep_hours       age    gender   gender2
# 0  8.368714e-16  1.542262 -1.016750 -0.999902
# 1  8.368714e-16  0.910386 -1.016750 -0.999902
# 2  1.168275e+00  1.668637 -1.016750 -0.999902
# 3  8.368714e-16  0.000000 -1.016750 -0.999902
# 4  8.368714e-16  1.710762  0.983526 -0.999902

# %%
#concatinate scaled_df with pred_dm_df replacing the pred_dm_df values with the scaled values
pred_dm_df[['sleep_hours', 'age', 'gender', 'gender2']] = scaled_df
pred_dm_df.head()
# Out:
#    speak_english  speak_english2  drink_alcohol  alcohol_per_day  \
# 0            1.0        1.000000       1.000000         1.000000
# 1            1.0        1.000000       1.000000         4.000000
# 2            1.0        1.099414       1.000000         3.482488
# 3            1.0        1.000000       1.299834         3.482488
# 4            1.0        1.099414       1.000000         3.482488
#
#    ear_infections   high_bp  measure_bp_home  measure_bp_doctor  \
# 0        2.000000  1.000000         2.000000           2.000000
# 1        2.000000  1.000000         1.000000           2.000000
# 2        2.000000  1.000000         2.000000           2.000000
# 3        1.811049  1.663415         1.755648           1.866625
# 4        2.000000  1.000000         1.000000           2.000000
#
#    cholesterol_checked  cholesterol_checked_1y  ...   height_in  \
# 0             1.395365                1.000000  ...   69.000000
# ...

# %%
#drop column menstruate from the dataframe
pred_dm_df = pred_dm_df.drop(columns = ['menstruate', 'gallbladder_cancer_age', 'nervous_cancer_age'])

# %%
#cast diabetes as integer
pred_dm_df['diabetes'] = pred_dm_df['diabetes'].astype(int)

# %%
#separate the features (x) from the target (Y)
y = pred_dm_df["diabetes"]
X = pred_dm_df.drop(columns="diabetes")

# %%
#create the training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (7631, 286)

# %%
#find column with value nan
pred_dm_df.columns[pred_dm_df.isna().any()]
# Out:
# Index([], dtype='object')

# %%
logistic_regression_model = LogisticRegression(max_iter = 2000, random_state = 9, solver = 'liblinear')
lr_model = logistic_regression_model.fit(X_train, y_train)

# %%
#generate the training predictions
training_predictions = lr_model.predict(X_train)

#generate the testing predictions
testing_predictions = logistic_regression_model.predict(X_test)

# %%
#create and save the confusion matrix for the training data
training_matrix = confusion_matrix(y_train, training_predictions)
training_matrix
# Out:
# array([[7027,   51],
#        [ 402,  151]])

# %%
#create and save the confusion matrix for the testing data
testing_matrix = confusion_matrix(y_test, testing_predictions)
testing_matrix
# Out:
# array([[2211,    0],
#        [ 184,    0]])

# %%
#create and save the training classification report
training_report = classification_report(y_train, training_predictions)
print(training_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96      6630
#          1.0       1.00      0.00      0.01       553
#
#     accuracy                           0.92      7183
#    macro avg       0.96      0.50      0.48      7183
# weighted avg       0.93      0.92      0.89      7183

# %%
#create and save the testing classification reprot
testing_report = classification_report(y_test, testing_predictions)
print(testing_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96      2211
#          1.0       0.00      0.00      0.00       184
#
#     accuracy                           0.92      2395
#    macro avg       0.46      0.50      0.48      2395
# weighted avg       0.85      0.92      0.89      2395
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
#get the feature importance array
importances = np.abs(logistic_regression_model.coef_[0])
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance':importances})
importance_df_sorted = importance_df.sort_values('Importance', ascending=False)
top_10_importances = importance_df_sorted.head(10)
print(top_10_importances)
# Out:
#                      Feature  Importance
# 79                       age    0.477431
# 40            general_health    0.249679
# 2                    high_bp    0.179725
# 4   cholesterol_prescription    0.176668
# 76         relative_diabetes    0.160066
# 3           high_cholesterol    0.158538
# 51                overweight    0.148304
# 25            Marital_Status    0.130014
# 17    milk_product_per_month    0.120475
# 56                 arthritis    0.088379
